# %%
import warnings

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

from astropy.io import fits
from astropy.table import Table

import pandas as pd
import numpy as np
np.seterr(divide='ignore')


warnings.filterwarnings("ignore", category=RuntimeWarning)


class HRCevt1:
    '''
    A more robust HRC EVT1 file. Includes explicit
    columns for every status bit, as well as calculated
    columns for the f_p, f_b plane for your boomerangs.
    Check out that cool new filtering algorithm!
    '''

    def __init__(self, evt1file):

        # Do a standard read in of the EVT1 fits table
        self.filename = evt1file
        self.hdulist = fits.open(evt1file)
        self.data = Table(self.hdulist[1].data)
        self.header = self.hdulist[1].header
        self.gti = self.hdulist[2].data
        self.hdulist.close()  # Don't forget to close your fits file!

        fp_u, fb_u, fp_v, fb_v = self.calculate_fp_fb()

        self.gti.starts = self.gti['START']
        self.gti.stops = self.gti['STOP']

        self.gtimask = []
        # for start, stop in zip(self.gti.starts, self.gti.stops):
        #     self.gtimask = (self.data["time"] > start) & (self.data["time"] < stop)

        self.gtimask = (self.data["time"] > self.gti.starts[0]) & (
            self.data["time"] < self.gti.stops[-1])

        self.data["fp_u"] = fp_u
        self.data["fb_u"] = fb_u
        self.data["fp_v"] = fp_v
        self.data["fb_v"] = fb_v

        # Make individual status bit columns with legible names
        self.data["AV3 corrected for ringing"] = self.data["status"][:, 0]
        self.data["AU3 corrected for ringing"] = self.data["status"][:, 1]
        self.data["Event impacted by prior event (piled up)"] = self.data["status"][:, 2]
        # Bit 4 (Python 3) is spare
        self.data["Shifted event time"] = self.data["status"][:, 4]
        self.data["Event telemetered in NIL mode"] = self.data["status"][:, 5]
        self.data["V axis not triggered"] = self.data["status"][:, 6]
        self.data["U axis not triggered"] = self.data["status"][:, 7]
        self.data["V axis center blank event"] = self.data["status"][:, 8]
        self.data["U axis center blank event"] = self.data["status"][:, 9]
        self.data["V axis width exceeded"] = self.data["status"][:, 10]
        self.data["U axis width exceeded"] = self.data["status"][:, 11]
        self.data["Shield PMT active"] = self.data["status"][:, 12]
        # Bit 14 (Python 13) is hardware spare
        self.data["Upper level discriminator not exceeded"] = self.data["status"][:, 14]
        self.data["Lower level discriminator not exceeded"] = self.data["status"][:, 15]
        self.data["Event in bad region"] = self.data["status"][:, 16]
        self.data["Amp total on V or U = 0"] = self.data["status"][:, 17]
        self.data["Incorrect V center"] = self.data["status"][:, 18]
        self.data["Incorrect U center"] = self.data["status"][:, 19]
        self.data["PHA ratio test failed"] = self.data["status"][:, 20]
        self.data["Sum of 6 taps = 0"] = self.data["status"][:, 21]
        self.data["Grid ratio test failed"] = self.data["status"][:, 22]
        self.data["ADC sum on V or U = 0"] = self.data["status"][:, 23]
        self.data["PI exceeding 255"] = self.data["status"][:, 24]
        self.data["Event time tag is out of sequence"] = self.data["status"][:, 25]
        self.data["V amp flatness test failed"] = self.data["status"][:, 26]
        self.data["U amp flatness test failed"] = self.data["status"][:, 27]
        self.data["V amp saturation test failed"] = self.data["status"][:, 28]
        self.data["U amp saturation test failed"] = self.data["status"][:, 29]
        self.data["V hyperbolic test failed"] = self.data["status"][:, 30]
        self.data["U hyperbolic test failed"] = self.data["status"][:, 31]
        self.data["Hyperbola test passed"] = np.logical_not(np.logical_or(
            self.data['U hyperbolic test failed'], self.data['V hyperbolic test failed']))
        self.data["Hyperbola test failed"] = np.logical_or(
            self.data['U hyperbolic test failed'], self.data['V hyperbolic test failed'])

        self.obsid = self.header["OBS_ID"]
        self.obs_date = self.header["DATE"]
        self.target = self.header["OBJECT"]
        self.detector = self.header["DETNAM"]
        self.grating = self.header["GRATING"]
        self.exptime = self.header["EXPOSURE"]

        self.numevents = len(self.data["time"])
        self.goodtimeevents = len(self.data["time"][self.gtimask])
        self.badtimeevents = self.numevents - self.goodtimeevents

        self.hyperbola_passes = np.sum(np.logical_or(
            self.data['U hyperbolic test failed'], self.data['V hyperbolic test failed']))
        self.hyperbola_failures = np.sum(np.logical_not(np.logical_or(
            self.data['U hyperbolic test failed'], self.data['V hyperbolic test failed'])))

        if self.hyperbola_passes + self.hyperbola_failures != self.numevents:
            print("Warning: Number of Hyperbola Test Failures and Passes ({}) does not equal total number of events ({}).".format(
                self.hyperbola_passes + self.hyperbola_failures, self.numevents))

        # Multidimensional columns don't grok with Pandas
        self.data.remove_column('status')
        self.data = self.data.to_pandas()

    def __str__(self):
        return "HRC EVT1 object with {} events. Data is packaged as a Pandas Dataframe".format(self.numevents)

    def calculate_fp_fb(self):
        '''
        Calculate the Fine Position (fp) and normalized central tap
        amplitude (fb) for the HRC U- and V- axes.

        Parameters
        ----------
        data : Astropy Table
            Table object made from an HRC evt1 event list. Must include the
            au1, au2, au3 and av1, av2, av3 columns.

        Returns
        -------
        fp_u, fb_u, fp_v, fb_v: float
            Calculated fine positions and normalized central tap amplitudes
            for the HRC U- and V- axes
        '''
        a_u = self.data["au1"]  # otherwise known as "a1"
        b_u = self.data["au2"]  # "a2"
        c_u = self.data["au3"]  # "a3"

        a_v = self.data["av1"]
        b_v = self.data["av2"]
        c_v = self.data["av3"]

        with np.errstate(invalid='ignore'):
            # Do the U axis
            fp_u = ((c_u - a_u) / (a_u + b_u + c_u))
            fb_u = b_u / (a_u + b_u + c_u)

            # Do the V axis
            fp_v = ((c_v - a_v) / (a_v + b_v + c_v))
            fb_v = b_v / (a_v + b_v + c_v)

        return fp_u, fb_u, fp_v, fb_v

    def threshold(self, img, bins):
        nozero_img = img.copy()
        nozero_img[img == 0] = np.nan

        # This is a really stupid way to threshold
        median = np.nanmedian(nozero_img)
        thresh = median*5

        thresh_img = nozero_img
        thresh_img[thresh_img < thresh] = np.nan
        thresh_img[:int(bins[1]/2), :] = np.nan
    #     thresh_img[:,int(bins[1]-5):] = np.nan
        return thresh_img


    def hyperscreen(self):
        '''
        Grant Tremblay's new algorithm. Screens events on a tap-by-tap basis.
        '''

        data = self.data

        #taprange = range(data['crsu'].min(), data['crsu'].max() + 1)
        taprange_u = range(data['crsu'].min() -1 , data['crsu'].max() + 1)
        taprange_v = range(data['crsv'].min() - 1, data['crsv'].max() + 1)

        bins = [200, 200]  # number of bins

        # Instantiate these empty dictionaries to hold our results
        u_axis_survivals = {}
        v_axis_survivals = {}

        for tap in taprange_u:
            # Do the U axis
            tapmask_u = data[data['crsu'] == tap].index.values
            if len(tapmask_u) < 2:
                continue
            keep_u = np.isfinite(data['fb_u'][tapmask_u])

            hist_u, xbounds_u, ybounds_u = np.histogram2d(
                data['fb_u'][tapmask_u][keep_u], data['fp_u'][tapmask_u][keep_u], bins=bins)
            thresh_hist_u = self.threshold(hist_u, bins=bins)

            posx_u = np.digitize(data['fb_u'][tapmask_u], xbounds_u)
            posy_u = np.digitize(data['fp_u'][tapmask_u], ybounds_u)
            hist_mask_u = (posx_u > 0) & (posx_u <= bins[0]) & (
                posy_u > -1) & (posy_u <= bins[1])

            # Values of the histogram where the points are
            hhsub_u = thresh_hist_u[posx_u[hist_mask_u] -
                                    1, posy_u[hist_mask_u] - 1]
            pass_fb_u = data['fb_u'][tapmask_u][hist_mask_u][np.isfinite(
                hhsub_u)]

            u_axis_survivals["U Axis Tap {:02d}".format(
                tap)] = pass_fb_u.index.values

        for tap in taprange_v:
            # Now do the V axis:
            tapmask_v = data[data['crsv'] == tap].index.values
            if len(tapmask_v) < 2:
                continue
            keep_v = np.isfinite(data['fb_v'][tapmask_v])

            hist_v, xbounds_v, ybounds_v = np.histogram2d(
                data['fb_v'][tapmask_v][keep_v], data['fp_v'][tapmask_v][keep_v], bins=bins)
            thresh_hist_v = self.threshold(hist_v, bins=bins)

            posx_v = np.digitize(data['fb_v'][tapmask_v], xbounds_v)
            posy_v = np.digitize(data['fp_v'][tapmask_v], ybounds_v)
            hist_mask_v = (posx_v > 0) & (posx_v <= bins[0]) & (
                posy_v > -1) & (posy_v <= bins[1])

            # Values of the histogram where the points are
            hhsub_v = thresh_hist_v[posx_v[hist_mask_v] -
                                    1, posy_v[hist_mask_v] - 1]
            pass_fb_v = data['fb_v'][tapmask_v][hist_mask_v][np.isfinite(
                hhsub_v)]

            v_axis_survivals["V Axis Tap {:02d}".format(
                tap)] = pass_fb_v.index.values

        # Done looping over taps

        u_all_survivals = np.concatenate(
            [x for x in u_axis_survivals.values()])
        v_all_survivals = np.concatenate(
            [x for x in v_axis_survivals.values()])

        # If the event passes both U- and V-axis tests, it survives
        all_survivals = np.intersect1d(u_all_survivals, v_all_survivals)
        survival_mask = np.isin(self.data.index.values, all_survivals)
        failure_mask = np.logical_not(survival_mask)

        num_survivals = sum(survival_mask)
        num_failures = sum(failure_mask)

        percent_tapscreen_rejected = round(
            ((num_failures / self.numevents) * 100), 2)

        # Do a sanity check to look for lost events. Shouldn't be any.
        if num_survivals + num_failures != self.numevents:
            print("WARNING: Total Number of survivals and failures does \
            not equal total events in the EVT1 file. Something is wrong!")

        legacy_hyperbola_test_survivals = sum(
            self.data['Hyperbola test passed'])
        legacy_hyperbola_test_failures = sum(
            self.data['Hyperbola test failed'])
        percent_legacy_hyperbola_test_rejected = round(
            ((legacy_hyperbola_test_failures / self.goodtimeevents) * 100), 2)

        percent_improvement_over_legacy_test = round(
            (percent_tapscreen_rejected - percent_legacy_hyperbola_test_rejected), 2)

        hyperscreen_results_dict = {"ObsID": self.obsid,
                                    "Target": self.target,
                                    "Exposure Time": self.exptime,
                                    "Detector": self.detector,
                                    "Number of Events": self.numevents,
                                    "Number of Good Time Events": self.goodtimeevents,
                                    "U Axis Survivals by Tap": u_axis_survivals,
                                    "V Axis Survivals by Tap": v_axis_survivals,
                                    "U Axis All Survivals": u_all_survivals,
                                    "V Axis All Survivals": v_all_survivals,
                                    "All Survivals (event indices)": all_survivals,
                                    "All Survivals (boolean mask)": survival_mask,
                                    "All Failures (boolean mask)": failure_mask,
                                    "Percent rejected by Tapscreen": percent_tapscreen_rejected,
                                    "Percent rejected by Hyperbola": percent_legacy_hyperbola_test_rejected,
                                    "Percent improvement": percent_improvement_over_legacy_test
                                    }

        return hyperscreen_results_dict

    def hyperbola(self, fb, a, b, h):
        '''Given the normalized central tap amplitude, a, b, and h,
        return an array of length len(fb) that gives a hyperbola.'''
        hyperbola = b * np.sqrt(((fb - h)**2 / a**2) - 1)

        return hyperbola

    def legacy_hyperbola_test(self, tolerance=0.035):
        '''
        Apply the hyperbolic test.
        '''

        # Remind the user what tolerance they're using
        # print("{0: <25}| Using tolerance = {1}".format(" ", tolerance))

        # Set hyperbolic coefficients, depending on whether this is HRC-I or -S
        if self.detector == "HRC-I":
            a_u = 0.3110
            b_u = 0.3030
            h_u = 1.0580

            a_v = 0.3050
            b_v = 0.2730
            h_v = 1.1
            # print("{0: <25}| Using HRC-I hyperbolic coefficients: ".format(" "))
            # print("{0: <25}|    Au={1}, Bu={2}, Hu={3}".format(" ", a_u, b_u, h_u))
            # print("{0: <25}|    Av={1}, Bv={2}, Hv={3}".format(" ", a_v, b_v, h_v))

        if self.detector == "HRC-S":
            a_u = 0.2706
            b_u = 0.2620
            h_u = 1.0180

            a_v = 0.2706
            b_v = 0.2480
            h_v = 1.0710
            # print("{0: <25}| Using HRC-S hyperbolic coefficients: ".format(" "))
            # print("{0: <25}|    Au={1}, Bu={2}, Hu={3}".format(" ", a_u, b_u, h_u))
            # print("{0: <25}|    Av={1}, Bv={2}, Hv={3}".format(" ", a_v, b_v, h_v))

        # Set the tolerance boundary ("width" of the hyperbolic region)

        h_u_lowerbound = h_u * (1 + tolerance)
        h_u_upperbound = h_u * (1 - tolerance)

        h_v_lowerbound = h_v * (1 + tolerance)
        h_v_upperbound = h_v * (1 - tolerance)

        # Compute the Hyperbolae
        with np.errstate(invalid='ignore'):
            zone_u_fit = self.hyperbola(self.data["fb_u"], a_u, b_u, h_u)
            zone_u_lowerbound = self.hyperbola(
                self.data["fb_u"], a_u, b_u, h_u_lowerbound)
            zone_u_upperbound = self.hyperbola(
                self.data["fb_u"], a_u, b_u, h_u_upperbound)

            zone_v_fit = self.hyperbola(self.data["fb_v"], a_v, b_v, h_v)
            zone_v_lowerbound = self.hyperbola(
                self.data["fb_v"], a_v, b_v, h_v_lowerbound)
            zone_v_upperbound = self.hyperbola(
                self.data["fb_v"], a_v, b_v, h_v_upperbound)

        zone_u = [zone_u_lowerbound, zone_u_upperbound]
        zone_v = [zone_v_lowerbound, zone_v_upperbound]

        # Apply the masks
        # print("{0: <25}| Hyperbolic masks for U and V axes computed".format(""))

        with np.errstate(invalid='ignore'):
            # print("{0: <25}| Creating U-axis mask".format(""), end=" |")
            between_u = np.logical_not(np.logical_and(
                self.data["fp_u"] < zone_u[1], self.data["fp_u"] > -1 * zone_u[1]))
            not_beyond_u = np.logical_and(
                self.data["fp_u"] < zone_u[0], self.data["fp_u"] > -1 * zone_u[0])
            condition_u_final = np.logical_and(between_u, not_beyond_u)

            # print(" Creating V-axis mask")
            between_v = np.logical_not(np.logical_and(
                self.data["fp_v"] < zone_v[1], self.data["fp_v"] > -1 * zone_v[1]))
            not_beyond_v = np.logical_and(
                self.data["fp_v"] < zone_v[0], self.data["fp_v"] > -1 * zone_v[0])
            condition_v_final = np.logical_and(between_v, not_beyond_v)

        mask_u = condition_u_final
        mask_v = condition_v_final

        hyperzones = {"zone_u_fit": zone_u_fit,
                      "zone_u_lowerbound": zone_u_lowerbound,
                      "zone_u_upperbound": zone_u_upperbound,
                      "zone_v_fit": zone_v_fit,
                      "zone_v_lowerbound": zone_v_lowerbound,
                      "zone_v_upperbound": zone_v_upperbound}

        hypermasks = {"mask_u": mask_u, "mask_v": mask_v}

        # print("{0: <25}| Hyperbolic masks created".format(""))
        # print("{0: <25}| ".format(""))
        return hyperzones, hypermasks


    def boomerang(self, mask=None, show=True, plot_legacy_zone=True, title=None, cmap=None, savepath=None, create_subplot=False, ax=None, rasterized=True):

        # You can plot the image on axes of a subplot by passing
        # that axis to this function. Here are some switches to enable that.

        if create_subplot is False:
            self.fig, self.ax = plt.subplots(figsize=(12, 8))
        elif create_subplot is True:
            if ax is None:
                self.ax = plt.gca()
            else:
                self.ax = ax

        if cmap is None:
            cmap = 'plasma'

        if mask is not None:
            self.ax.scatter(self.data['fb_u'], self.data['fp_u'],
                            c=self.data['sumamps'], cmap='bone', s=0.3, alpha=0.8, rasterized=rasterized)

            frame = self.ax.scatter(self.data['fb_u'][mask], self.data['fp_u'][mask],
                                    c=self.data['sumamps'][mask], cmap=cmap, s=0.5, rasterized=rasterized)

        else:
            frame = self.ax.scatter(self.data['fb_u'], self.data['fp_u'],
                                    c=self.data['sumamps'], cmap=cmap, s=0.5, rasterized=rasterized)

        if plot_legacy_zone is True:
            hyperzones, hypermasks = self.legacy_hyperbola_test(
                tolerance=0.035)
            self.ax.plot(self.data["fb_u"], hyperzones["zone_u_lowerbound"],
                         'o', markersize=0.3, color='black', alpha=0.8, rasterized=rasterized)
            self.ax.plot(self.data["fb_u"], -1 * hyperzones["zone_u_lowerbound"],
                         'o', markersize=0.3, color='black', alpha=0.8, rasterized=rasterized)

            self.ax.plot(self.data["fb_u"], hyperzones["zone_u_upperbound"],
                         'o', markersize=0.3, color='black', alpha=0.8, rasterized=rasterized)
            self.ax.plot(self.data["fb_u"], -1 * hyperzones["zone_u_upperbound"],
                         'o', markersize=0.3, color='black', alpha=0.8, rasterized=rasterized)

        self.ax.grid(False)

        if title is None:
            self.ax.set_title('{} | {} | ObsID {} | {} ksec | {} counts'.format(
                self.target, self.detector, self.obsid, round(self.exptime / 1000, 1), self.numevents))
        else:
            self.ax.set_title(title)

        self.ax.set_ylim(-1.1, 1.1)
        self.ax.set_xlim(-0.1, 1.1)

        self.ax.set_ylabel(r'Fine Position $f_p$ $(C-A)/(A + B + C)$')
        self.ax.set_xlabel(
            r'Normalized Central Tap Amplitude $f_b$ $B / (A+B+C)$')

        if create_subplot is False:
            self.cbar = plt.colorbar(frame, pad=-0.005)
            self.cbar.set_label("SUMAMPS")

        if show is True:
            plt.show()

        if savepath is not None:
            plt.savefig(savepath, dpi=150, bbox_inches='tight')
            print('Saved boomerang figure to: {}'.format(savepath))


    def image(self, masked_x=None, masked_y=None, xlim=None, ylim=None, detcoords=False, title=None, cmap=None, show=True, savepath=None, create_subplot=False, ax=None):
        '''
        Create a quicklook image, in detector or sky coordinates, of the 
        observation. The image will be binned to 400x400. 
        '''

        # Create the 2D histogram
        nbins = (400, 400)

        if masked_x is not None and masked_y is not None:
            x = masked_x
            y = masked_y
            img_data, yedges, xedges = np.histogram2d(y, x, nbins)
        else:
            if detcoords is False:
                x = self.data['x'][self.gtimask]
                y = self.data['y'][self.gtimask]
            elif detcoords is True:
                x = self.data['detx'][self.gtimask]
                y = self.data['dety'][self.gtimask]
            img_data, yedges, xedges = np.histogram2d(y, x, nbins)

        extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

        # Create the Figure
        styleplots()

        # You can plot the image on axes of a subplot by passing
        # that axis to this function. Here are some switches to enable that.
        if create_subplot is False:
            self.fig, self.ax = plt.subplots()
        elif create_subplot is True:
            if ax is None:
                self.ax = plt.gca()
            else:
                self.ax = ax

        self.ax.grid(False)

        if cmap is None:
            cmap = 'viridis'

        self.ax.imshow(img_data, extent=extent, norm=LogNorm(),
                       interpolation=None, cmap=cmap, origin='lower')

        if title is None:
            self.ax.set_title("ObsID {} | {} | {} | {:,} events".format(
                self.obsid, self.target, self.detector, self.goodtimeevents))
        else:
            self.ax.set_title("{}".format(title))
        if detcoords is False:
            self.ax.set_xlabel("Sky X")
            self.ax.set_ylabel("Sky Y")
        elif detcoords is True:
            self.ax.set_xlabel("Detector X")
            self.ax.set_ylabel("Detector Y")
            
        if xlim is not None:
            self.ax.set_xlim(xlim)
        if ylim is not None:
            self.ax.set_ylim(ylim)

        if show is True:
            plt.show(block=True)

        if savepath is not None:
            plt.savefig('{}'.format(savepath))
            print("Saved image to {}".format(savepath))


def styleplots():

    mpl.rcParams['agg.path.chunksize'] = 10000

    # Make things pretty
    plt.style.use('ggplot')

    labelsizes = 10

    plt.rcParams['font.size'] = labelsizes
    plt.rcParams['axes.titlesize'] = 12
    plt.rcParams['axes.labelsize'] = labelsizes
    plt.rcParams['xtick.labelsize'] = labelsizes
    plt.rcParams['ytick.labelsize'] = labelsizes

# %%
from astropy.io import fits
import os

# %%
os.listdir('../tests/data/')
# Out:
# ['hrcI_evt1_testfile.fits.gz', 'hrcS_evt1_testfile.fits.gz']

# %%
fitsfile = '../tests/data/hrcS_evt1_testfile.fits.gz'
obs = HRCevt1(fitsfile)

# %%
obs.image(obs.data['detx'][obs.gtimask], obs.data['dety'][obs.gtimask], xlim=(26000, 41000), ylim=(31500, 34000))

# %%
results = obs.hyperscreen()

# %%
obs.image(obs.data['detx'][results['All Failures (boolean mask)']], obs.data['dety'][results['All Failures (boolean mask)']], xlim=(26000, 41000), ylim=(31500, 34000))

# %%
obs.data['crsv'].min()
# Out:
# 4

# %%
obs.data['crsv'].max()
# Out:
# 58

# %%
obs.data['crsv']
# Out:
# 0        38
# 1         6
# 2        10
# 3        44
# 4        55
#          ..
# 50755    35
# 50756     9
# 50757    10
# 50758     2
# 50759     9
# Name: crsv, Length: 50760, dtype: int16

# %%
obs.numevents
# Out:
# 50760

# %%
from astropy.io import fits

# %%
header = fits.getheader(fitsfile, 1)

# %%
header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   74 / width of table in bytes
# NAXIS2  =                50760 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   25 / number of fields in each row
# EXTNAME = 'EVENTS  '           / name of this binary table extension
# HDUNAME = 'EVENTS  '           / ASCDM block name
# COMMENT                               +------------------+
# COMMENT                               | AXAF FITS   File |
# COMMENT                               +------------------+
# COMMENT  *********************************************************
# COMMENT  >    This file is written following certain AXAF-ASC    <
# COMMENT  >    conventions which are documented in ASC-FITS-2.0   <
# COMMENT  *********************************************************
# COMMENT                        / Configuration control block--------------------
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# TITLE   = 'SEARCHING FOR X-RAY TRANSIENTS IN M31 WITH CHANDRA AND HST' / Proposa
# OBSERVER= 'Dr. Michael Garcia' / Principal investigator
# OBJECT  = 'M31-S2  '           / Source name
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# ORIGIN  = 'ASC     '           / Source of FITS file
# CREATOR = 'hrc_process_events - Version DS 8.4' / tool that created this output
# ASCDSVER= '8.4.5   '           / Processing system revision
# TLMVER  = 'P009    '           / Telemetry revision number (IP&CL)
# RA_PNT  =  1.0109821091654E+01 / [deg] Pointing RA
# DEC_PNT =  4.0674572254271E+01 / [deg] Pointing Dec
# ROLL_PNT=  1.4960963115648E+02 / [deg] Pointing Roll
# RA_TARG =  1.0112917000000E+01 / [deg] Observer's specified target RA
# DEC_TARG=  4.0670000000000E+01 / [deg] Observer's specified target Dec
# DEFOCUS =  1.4262644205751E-03 / [mm] SIM defocus
# RA_NOM  =  1.0109821091654E+01 / [deg] Nominal RA
# DEC_NOM =  4.0674572254271E+01 / [deg] Nominal Dec
# ROLL_NOM=  1.4960963115648E+02 / [deg] Nominal Roll
# REVISION=                    4 / Processing version of data
# CHECKSUM= 'RKEgRHEZRHEdRHEZ'   / HDU checksum updated 2012-09-23T15:11:52
# DATASUM = '1001617376'         / data unit checksum updated 2012-09-23T15:05:02
# CONTENT = 'EVT1    '           / What data product
# DETNAM  = 'HRC-I   '           / Detector
# OBS_ID  = '2886    '           / Observation id
# HDUSPEC = 'HRC Level 0 Data Products ICD Version 1.5' / ICD reference
# HDUDOC  = 'ASC-FITS-2.0: McDowell, Rots: ASC FITS File Designers Guide'
# HDUVERS = '1.0.0   '
# HDUCLASS= 'OGIP    '
# ASOLFILE= 'pcadf116336524N003_asol1.fits' / aspect offset files
# ADCCORF = 'NONE    '           / ADC correction file used
# BPIXFILE= 'hrcf02886_000N004_bpix1.fits' / Bad pixel file used
# GAINCORF= 'hrciD2000-12-12sampgainN0001.fits' / gain correction file used
# DEGAP   = 'hrciD1999-07-22gaplookupN0004.fits'
# HYPFILE = 'hrciD1999-07-22fptestN0003.fits' / hyperbolic test file used
# TAPRING = 'hrciD1999-07-22tapringN0002.fits' / tapring coeff file used
# FLATFILE= 'hrciD1999-07-22eftestN0001.fits' / flatness test file used
# SATFILE = 'hrciD1999-07-22sattestN0002.fits' / saturation test file used
# AMPSFFIL= 'hrciD1999-07-22amp_sf_corN0001.fits' / AMF_SF Correction file used
# WIDTHRES=                    2 / width threshold
# RAND_SKY=  0.0000000000000E+00 / pixel randomization
# HDUCLAS1= 'EVENTS  '
# HDUCLAS2= 'ALL     '
# COMMENT This FITS file may contain long string keyword values that are
# SEQ_NUM = '600223  '           / Sequence number
# COMMENT continued over multiple keywords.  This convention uses the  '&'
# COMMENT character at the end of a string which is then continued
# DS_IDENT= 'ADS/Sa.CXO#obs/02886' / dataset identifier
# DATACLAS= 'OBSERVED'           / default
# RADESYS = 'ICRS    '           / default
# MJD_OBS =  5.2160481101044E+04 / Modified Julian date of observation
# OBI_NUM =                    0 / Obi number
# COMMENT on subsequent keywords whose name = 'CONTINUE'
# COMMENT                        / Time information block-------------------------
# DATE    = '2012-09-23T15:04:15' / Date and time of file creation
# DATE-OBS= '2001-09-08T11:32:47' / Observation start date
# DATE-END= '2001-09-08T12:03:59' / Observation end date
# TIMESYS = 'TT      '           / Time system
# MJDREF  =  5.0814000000000E+04 / [d] MJD zero point for times
# TIMEZERO=  0.0000000000000E+00 / [s] Clock correction
# TIMEUNIT= 's       '           / Time unit
# BTIMNULL=  1.1451603855832E+08 / Basic Time offset (s)
# BTIMRATE=  2.5625001011232E-01 / Basic Time clock rate (s/VCDUcount)
# BTIMDRFT=  1.9298135452135E-18 / Basic Time clock drift (s/VCDUcount^2)
# BTIMCORR=  0.0000000000000E+00 / Correction applied to basic time rate (s)
# TIMEREF = 'LOCAL   '           / Time reference (barycenter/local)
# TASSIGN = 'SATELLITE'          / Time assigned by clock
# CLOCKAPP=                    T / Clock correction applied
# OBS_MODE= 'POINTING'           / Observation mode
# TIERRELA=  1.0000000000000E-09 / Short-term clock stability
# TIERABSO=  5.0000000000000E-05 / Absolute precision of clock correction
# TIMVERSN= 'ASC-FITS-2'         / Timing system definition
# TSTART  =  1.1633596713019E+08 / [s] Observation start time (MET)
# TSTOP   =  1.1633783929276E+08 / [s] Observation end time (MET)
# STARTMJF=                55485 / Major frame ctr value at start of data
# STARTMNF=                   88 / Start minor frame ctr at start of data
# STARTOBT=  0.0000000000000E+00 / On-Board MET close to STARTMJF and STARTMNF
# STOPMJF =                55501 / Major frame ctr value at stop of data
# STOPMNF =                   96 / Stop minor frame ctr at end of data
# SIM_X   = -1.0388663562383E+00 / [mm] SIM focus pos
# SIM_Y   =  0.0000000000000E+00 / [mm] SIM orthogonal axis pos
# SIM_Z   =  1.2698549430529E+02 / [mm] SIM translation stage pos
# FOC_LEN =  1.0070000000000E+04 / [mm] HRMA focal length
# TIMEPIXR=  5.0000000000000E-01 / Time stamp reference as bin fraction
# GRATING = 'NONE    '           / Grating
# TIMEDEL =  1.5625000000000E-05 / Time resolution of data (in seconds)
# COMMENT                        / Observation information block------------------
# MISSION = 'AXAF    '           / Mission
# TELESCOP= 'CHANDRA '           / Telescope
# INSTRUME= 'HRC     '           / Instrument
# TLM_FMT =                    1 / Format in which this data was telemetered
# DATAMODE= 'OBSERVING'          / Data mode
# COMMENT                        / Column format information block----------------
# COMMENT                        / History information block----------------------
# HISTNUM =                  363
# HISTORY  TOOL  :hrcse                                                   ASC00001
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//TP_HDE____4ASC00002
# HISTORY  CONT  :64576508n794/input/hrcf116335684N003_hrc0.strip         ASC00003
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/hrcds_ASC00004
# HISTORY  CONT  :fmt1.strip@@/main/4                                     ASC00005
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/hrcds_ASC00006
# HISTORY  CONT  :file_info.dat@@/main/7                                  ASC00007
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/hrcse_ASC00008
# HISTORY  CONT  :file_info.dat@@/main/6                                  ASC00009
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/hrcse_ASC00010
# HISTORY  CONT  :group_info.dat@@/main/6                                 ASC00011
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/hrcse_ASC00012
# LIMFILE1= '/home/ascds/DS.rap/data/hrc_gti_all_lim.fits' / GTI Limit file
# HISTORY  CONT  :dp_info.dat@@/main/13                                   ASC00013
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/commonASC00014
# HISTORY  CONT  :_dp_info.dat@@/main/19                                  ASC00015
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/hrcse_ASC00016
# HISTORY  CONT  :decom_info.dat@@/main/15                                ASC00017
# HISTORY  PARM  :template=/vobs/ASC_DR_TLM/src/dr/tlm/template_dir/hrcse_ASC00018
# HISTORY  CONT  :cal_info.dat@@/main/3                                   ASC00019
# HISTORY  TOOL  :hrc_rebin   2012-09-23T14:49:04                         ASC00020
# HISTORY  PARM  :evtFile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L05__ASC00021
# HISTORY  CONT  :_464698167n898/input/hrcf116335967N003_evt0.lis         ASC00022
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L05___46469816ASC00023
# HISTORY  CONT  :7n898/input/hrcf116335684N003_evt0.fits                 ASC00024
# HISTORY  PARM  :spsFile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L05__ASC00025
# HISTORY  CONT  :_464698167n898/input/hrcf116335967N003_ss0.lis          ASC00026
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L05___46469816ASC00027
# HISTORY  CONT  :7n898/input/hrcf116335684N003_ss0.fits                  ASC00028
# HISTORY  PARM  :intvFile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L05__ASC00029
# HISTORY  CONT  :_464698167n898/output/hrcf116335967N003_hmt0a.fits      ASC00030
# HISTORY  PARM  :outdir=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L05___4ASC00031
# HISTORY  CONT  :64698167n898/output                                     ASC00032
# HISTORY  PARM  :clobber=no                                              ASC00033
# HISTORY  PARM  :verbose=0                                               ASC00034
# HISTORY  TOOL  :dmhedit   2012-09-23T14:49:08                           ASC00035
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L05___4ASC00036
# HISTORY  CONT  :64698167n898/output/hrc*0a.fits,/dsops/repro4/sdp.1/opusASC00037
# HISTORY  CONT  :/prs_run/tmp//HRC_L05___464698167n898/output/hrcf1163359ASC00038
# HISTORY  CONT  :67N003_hmt0a.fits                                       ASC00039
# HISTORY  PARM  :filelist=                                               ASC00040
# HISTORY  PARM  :operation=add                                           ASC00041
# HISTORY  PARM  :key=REVISION                                            ASC00042
# HISTORY  PARM  :value=3                                                 ASC00043
# HISTORY  PARM  :datatype=long                                           ASC00044
# HISTORY  PARM  :unit=                                                   ASC00045
# HISTORY  PARM  :comment=                                                ASC00046
# HISTORY  PARM  :verbose=0                                               ASC00047
# HISTORY  TOOL  :hrc_correct_times   2012-09-23T15:04:05                 ASC00048
# HISTORY  PARM  :infile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00049
# HISTORY  CONT  :464699060n941/input/hrcf02886_000N004_evt0.lis          ASC00050
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00051
# HISTORY  CONT  :0n941/input/hrcf116335967N003_evt0a.fits                ASC00052
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00053
# HISTORY  CONT  :0n941/input/hrcf116336496N003_evt0a.fits                ASC00054
# HISTORY  PARM  :hkfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00055
# HISTORY  CONT  :464699060n941/input/hrcf02886_000N004_hk0.lis           ASC00056
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00057
# HISTORY  CONT  :0n941/input/hrcf116335684N003_hk0.fits                  ASC00058
# HISTORY  PARM  :outfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1___ASC00059
# HISTORY  CONT  :_464699060n941/output/hrcf02886_000N004_tmp_evt1.lis    ASC00060
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00061
# HISTORY  CONT  :0n941/output/hrcf116335967N003_tmp_evt1.fits            ASC00062
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00063
# HISTORY  CONT  :0n941/output/hrcf116336496N003_tmp_evt1.fits            ASC00064
# HISTORY  PARM  :max_delta_time=0.1                                      ASC00065
# HISTORY  PARM  :clobber=no                                              ASC00066
# HISTORY  PARM  :verbose=0                                               ASC00067
# TTYPE1  = 'time    '           / Time tag (TT)
# TFORM1  = '1D      '           / format of field
# TUNIT1  = 's       '
# TTYPE2  = 'crsv    '           / Coarse position V axis
# TFORM2  = '1I      '           / format of field
# TTYPE3  = 'crsu    '           / Coarse position U axis
# TFORM3  = '1I      '           / format of field
# TTYPE4  = 'amp_sf  '           / Amplitude scale factor
# TFORM4  = '1I      '           / format of field
# TTYPE5  = 'av1     '           / V axis ADC 1
# TFORM5  = '1I      '           / format of field
# TTYPE6  = 'av2     '           / V axis ADC 2
# TFORM6  = '1I      '           / format of field
# TTYPE7  = 'av3     '           / V axis ADC 3
# TFORM7  = '1I      '           / format of field
# TTYPE8  = 'au1     '           / U axis ADC 1
# TFORM8  = '1I      '           / format of field
# TTYPE9  = 'au2     '           / U axis ADC 2
# TFORM9  = '1I      '           / format of field
# TTYPE10 = 'au3     '           / U axis ADC 3
# TFORM10 = '1I      '           / format of field
# TTYPE11 = 'rawx    '           / Raw coords
# TFORM11 = '1J      '           / format of field
# TUNIT11 = 'pixel   '
# TTYPE12 = 'rawy    '           / Raw coords
# TFORM12 = '1J      '           / format of field
# TUNIT12 = 'pixel   '
# TLMIN11 =                    0
# TLMAX11 =                16383
# TLMIN12 =                    0
# TLMAX12 =                16383
# TTYPE13 = 'chipx   '           / Chip coords
# TFORM13 = '1I      '           / format of field
# TUNIT13 = 'pixel   '
# TTYPE14 = 'chipy   '           / Chip coords
# TFORM14 = '1I      '           / format of field
# TUNIT14 = 'pixel   '
# TLMIN13 =                    1
# TLMAX13 =                16384
# TLMIN14 =                    1
# TLMAX14 =                16384
# TTYPE15 = 'tdetx   '           / Tdet coords
# TFORM15 = '1J      '           / format of field
# TUNIT15 = 'pixel   '
# TTYPE16 = 'tdety   '           / Tdet coords
# TFORM16 = '1J      '           / format of field
# TUNIT16 = 'pixel   '
# TLMIN15 =                    1
# TLMAX15 =                16384
# TLMIN16 =                    1
# TLMAX16 =                16384
# TTYPE17 = 'detx    '           / Det coords
# TFORM17 = '1E      '           / format of field
# TUNIT17 = 'pixel   '
# TTYPE18 = 'dety    '           / Det coords
# TFORM18 = '1E      '           / format of field
# TUNIT18 = 'pixel   '
# TLMIN17 =        5.0000000E-01
# TLMAX17 =        3.2768500E+04
# TLMIN18 =        5.0000000E-01
# TLMAX18 =        3.2768500E+04
# TTYPE19 = 'x       '           / Sky coords
# TFORM19 = '1E      '           / format of field
# TUNIT19 = 'pixel   '
# TTYPE20 = 'y       '           / Sky coords
# TFORM20 = '1E      '           / format of field
# TUNIT20 = 'pixel   '
# TLMIN19 =        5.0000000E-01
# TLMAX19 =        3.2768500E+04
# TLMIN20 =        5.0000000E-01
# TLMAX20 =        3.2768500E+04
# TTYPE21 = 'pha     '           / Pulse height
# TFORM21 = '1I      '           / format of field
# TUNIT21 = 'chan    '
# TTYPE22 = 'pi      '           / Pulse Invariant
# TFORM22 = '1I      '           / format of field
# TUNIT22 = 'chan    '
# TTYPE23 = 'sumamps '           / Sum of all amp readouts
# TFORM23 = '1I      '           / format of field
# TLMIN23 =                    0
# TLMAX23 =                24570
# TTYPE24 = 'chip_id '           / Chip ID
# TFORM24 = '1I      '           / format of field
# TLMIN24 =                    0
# TLMAX24 =                    0
# TTYPE25 = 'status  '           / Event status bits
# TFORM25 = '32X     '           / format of field
# HISTORY  TOOL  :hrc_process_events   2012-09-23T15:04:42                ASC00068
# HISTORY  PARM  :infile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00069
# HISTORY  CONT  :464699060n941/output/hrcf02886_000N004_tmp_evt1.lis     ASC00070
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00071
# HISTORY  CONT  :0n941/output/hrcf116335967N003_tmp_evt1.fits            ASC00072
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00073
# HISTORY  CONT  :0n941/output/hrcf116336496N003_tmp_evt1.fits            ASC00074
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00075
# HISTORY  CONT  :464699060n941/output/hrcf02886_000N004_evt1.fits        ASC00076
# HISTORY  PARM  :badpixfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1_ASC00077
# HISTORY  CONT  :___464699060n941/output/hrcf02886_000N004_bpix1.fits    ASC00078
# HISTORY  PARM  :acaofffile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1ASC00079
# HISTORY  CONT  :____464699060n941/input/pcadf02886_000N004_asol1.lis    ASC00080
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00081
# HISTORY  CONT  :0n941/input/pcadf116336524N003_asol1.fits[time=116335967ASC00082
# RANGELEV=                  116 / range_switch_level
# AMPSFCOR=                    T / TRUE=apply_amp_sf_corr;  FALSE=NOT_apply;
# ACSYS1  = 'RAW:AXAF-HRC-1.1'   / reference for raw chip coord system
# ACSYS2  = 'CHIP:AXAF-HRC-1.1'  / reference for degap corrected chip coord system
# ACSYS3  = 'TDET:HRC-2.4I'      / reference for tiled detector coord system
# ACSYS4  = 'DET:ASC-FP-2.1'     / reference for focal plane coord system
# ACSYS5  = 'SKY:ASC-FP-2.1'     / reference for sky coord system
# ASPTYPE = 'KALMAN  '
# ONTIME  =  9.5325003767014E+02 / [s]
# DTCOR   =  9.9440906000473E-01 / Dead time correction
# LIVETIME=  9.4792047390904E+02 / Ontime multiplied by DTCOR
# EXPOSURE=  9.4792047390904E+02 / Total exposure time, with all known corr. appl.
# AIMPFILE= 'telD1999-07-23aimptsN0002.fits'
# GEOMFILE= 'telD1999-07-23geomN0006.fits'
# SKYFILE = 'telD1999-07-23skyN0002.fits'
# TDETFILE= 'telD1999-07-23tdetN0001.fits'
# SHELLFIL= 'telD1999-07-23sgeomN0001.fits'
# DTFFILE = 'hrcf02886_000N004_dtf1.fits'
# MASKFILE= 'hrcf02886_000N004_msk1.fits'
# FLTFILE = 'hrcf02886_000N004_std_flt1.fits'
# DY_AVG  =  1.3215637350000E-01 / [mm] Mean DY during observation
# DZ_AVG  =  2.1384976744000E-01 / [mm] Mean DZ during observation
# DTH_AVG =  8.1399432962000E-03 / [deg] Mean DTHETA during observation
# CALDBVER= '4.5.1.1 '
# HISTORY  CONT  :.1301900:116337839.2927600]                             ASC00083
# HISTORY  PARM  :alignmentfile=@/dsops/repro4/sdp.1/opus/prs_run/tmp//HRCASC00084
# HISTORY  CONT  :_L1____464699060n941/input/pcadf02886_000N004_asol1.lis ASC00085
# HISTORY  STCK  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00086
# HISTORY  CONT  :0n941/input/pcadf116336524N003_asol1.fits[time=116335967ASC00087
# HISTORY  CONT  :.1301900:116337839.2927600]                             ASC00088
# HISTORY  PARM  :obsfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00089
# HISTORY  CONT  :464699060n941/input/axaff02886_000N003_obs0a.par        ASC00090
# HISTORY  PARM  :geompar=geom                                            ASC00091
# HISTORY  PARM  :do_ratio=yes                                            ASC00092
# HISTORY  PARM  :do_amp_sf_cor=yes                                       ASC00093
# HISTORY  PARM  :gainfile=CALDB                                          ASC00094
# HISTORY  PARM  :ADCfile=NONE                                            ASC00095
# HISTORY  PARM  :degapfile=CALDB                                         ASC00096
# HISTORY  PARM  :hypfile=CALDB                                           ASC00097
# HISTORY  PARM  :ampsfcorfile=CALDB                                      ASC00098
# HISTORY  PARM  :tapfile=CALDB                                           ASC00099
# HISTORY  PARM  :ampsatfile=CALDB                                        ASC00100
# HISTORY  PARM  :evtflatfile=CALDB                                       ASC00101
# HISTORY  PARM  :badfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00102
# HISTORY  CONT  :464699060n941/output/hrcf02886_000N004_bad_evt1.fits    ASC00103
# HISTORY  PARM  :logfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00104
# HISTORY  CONT  :464699060n941/output/hrc_process_events.log             ASC00105
# HISTORY  PARM  :instrume=HRC-I                                          ASC00106
# HISTORY  PARM  :eventdef={d:time,s:crsv,s:crsu,s:amp_sf,s:av1,s:av2,s:avASC00107
# HISTORY  CONT  :3,s:au1,s:au2,s:au3,l:raw,s:chip,l:tdet,f:det,f:sky,s:phASC00108
# HISTORY  CONT  :a,s:pi,s:sumamps,s:chip_id,x:status}                    ASC00109
# HISTORY  PARM  :badeventdef={d:time,s:crsu,s:crsv,s:au1,s:au2,s:au3,s:avASC00110
# HISTORY  CONT  :1,s:av2,s:av3,s:pha}                                    ASC00111
# HISTORY  PARM  :grid_ratio=0.5                                          ASC00112
# HISTORY  PARM  :pha_ratio=0.5                                           ASC00113
# HISTORY  PARM  :wire_charge=0                                           ASC00114
# HISTORY  PARM  :cfu1=0                                                  ASC00115
# HISTORY  PARM  :cfu2=0                                                  ASC00116
# HISTORY  PARM  :cfv1=0                                                  ASC00117
# HISTORY  PARM  :cfv2=0                                                  ASC00118
# HISTORY  PARM  :time_offset=0                                           ASC00119
# HISTORY  PARM  :amp_gain=75                                             ASC00120
# HISTORY  PARM  :rand_seed=1                                             ASC00121
# HISTORY  PARM  :rand_pix_size=0                                         ASC00122
# HISTORY  PARM  :tstart=TSTART                                           ASC00123
# HISTORY  PARM  :tstop=TSTOP                                             ASC00124
# HISTORY  PARM  :start=coarse                                            ASC00125
# HISTORY  PARM  :stop=sky                                                ASC00126
# HISTORY  PARM  :stdlev1={d:time,s:crsv,s:crsu,s:amp_sf,s:av1,s:av2,s:av3ASC00127
# HISTORY  CONT  :,s:au1,s:au2,s:au3,l:raw,s:chip,l:tdet,f:det,f:sky,s:phaASC00128
# HISTORY  CONT  :,s:pi,s:sumamps,s:chip_id,x:status}                     ASC00129
# HISTORY  PARM  :badlev1={d:time,s:crsu,s:crsv,s:au1,s:au2,s:au3,s:av1,s:ASC00130
# HISTORY  CONT  :av2,s:av3,s:pha}                                        ASC00131
# HISTORY  PARM  :hsilev1={d:time,s:crsu,s:crsv,s:au1,s:au2,s:au3,s:av1,s:ASC00132
# HISTORY  CONT  :av2,s:av3,s:chipx,s:chipy,s:tdetx,s:tdety,s:x,s:y,l:fpz,ASC00133
# HISTORY  CONT  :s:pha,s:vstat,s:estat}                                  ASC00134
# HISTORY  PARM  :simlev1={l:tick,i:scifr,i:mjf,s:mnf,s:evtctr,s:crsu,s:crASC00135
# HISTORY  CONT  :sv,s:au1,s:au2,s:au3,s:av1,s:av2,s:av3,s:tdetx,s:tdety,sASC00136
# HISTORY  CONT  ::pha,s:vstat,s:estat}                                   ASC00137
# HISTORY  PARM  :fltlev1={d:time,s:crsv,s:crsu,s:amp_sf,s:av1,s:av2,s:av3ASC00138
# HISTORY  CONT  :,s:au1,s:au2,s:au3,s:chipx,s:chipy,l:tdetx,l:tdety,s:detASC00139
# HISTORY  CONT  :x,s:dety,s:x,s:y,s:pha,s:sumamps,s:chip_id,l:status}    ASC00140
# HISTORY  PARM  :clobber=no                                              ASC00141
# HISTORY  PARM  :verbose=0                                               ASC00142
# HISTORY  PARM  :PIXLIB Version: 4.0.0                                   ASC00143
# HISTORY  PARM  :******     PIXLIB Parameter File      *****             ASC00144
# HISTORY  PARM  :/dsops/repro4/sdp.1/opus/prs_run/tmp/HRC_L1____464699060ASC00145
# HISTORY  CONT  :n941/output/param/geom.par:                             ASC00146
# HISTORY  PARM  :instruments  = /data/CALDB/sdp/data/chandra/default/geomASC00147
# HISTORY  CONT  :/telD1999-07-23geomN0006.fits(CALDB)                    ASC00148
# HISTORY  PARM  :aimpoints    = /data/CALDB/sdp/data/chandra/default/aimpASC00149
# HISTORY  CONT  :ts/telD1999-07-23aimptsN0002.fits(CALDB)                ASC00150
# HISTORY  PARM  :tdet         = /data/CALDB/sdp/data/chandra/default/tdetASC00151
# HISTORY  CONT  :/telD1999-07-23tdetN0001.fits(CALDB)                    ASC00152
# HISTORY  PARM  :sky          = /data/CALDB/sdp/data/chandra/default/sky/ASC00153
# HISTORY  CONT  :telD1999-07-23skyN0002.fits(CALDB)                      ASC00154
# HISTORY  PARM  :shell        = /data/CALDB/sdp/data/chandra/default/sgeoASC00155
# HISTORY  CONT  :m/telD1999-07-23sgeomN0001.fits(CALDB)                  ASC00156
# HISTORY  PARM  :obsfile      = 2001-09-08T11:32:47(/dsops/repro4/sdp.1/oASC00157
# HISTORY  CONT  :pus/prs_run/tmp//HRC_L1____464699060n941/input/axaff0288ASC00158
# HISTORY  CONT  :6_000N003_obs0a.par)                                    ASC00159
# HISTORY  PARM  :******     PIXLIB System Configuration      ******      ASC00160
# HISTORY  PARM  :Telescope = FLIGHT                                      ASC00161
# HISTORY  PARM  :Focal Length (mm) = 10070.000                           ASC00162
# HISTORY  PARM  :Detector = HRC-I                                        ASC00163
# HISTORY  PARM  :Focal Plane Sys. = FP-2.1                               ASC00164
# HISTORY  PARM  :Tiled Detector Plane Sys. = HRC-2.4I                    ASC00165
# HISTORY  PARM  :SIM Offset (mm) = (1.04 0.978 -132.028)                 ASC00166
# HISTORY  PARM  :Aim Point(NONE) (mm) = (-1.03887 0 126.985)             ASC00167
# HISTORY  PARM  :Grating Arm = HEG                                       ASC00168
# HISTORY  PARM  :Grating Order =  1                                      ASC00169
# HISTORY  PARM  :Dispersion Plane Sys. = ASC-GDP-1.1                     ASC00170
# HISTORY  PARM  :Rowland Circle (mm) = 8632.48                           ASC00171
# HISTORY  PARM  :Stage Ang (arc-mins) = (0 0 0)                          ASC00172
# HISTORY  PARM  :Stage Pos (mm) = (0 0 0)                                ASC00173
# HISTORY  PARM  :Pitch-Yaw (arc-mins) = (0 0           )                 ASC00174
# TLMIN2  =                    0
# TLMAX2  =                   63
# TLMIN3  =                    0
# TLMAX3  =                   63
# TLMIN4  =                    0
# TLMAX4  =                    3
# TLMIN5  =                    0
# TLMAX5  =                 4095
# TLMIN6  =                    0
# TLMAX6  =                 4095
# TLMIN7  =                    0
# TLMAX7  =                 4095
# TLMIN8  =                    0
# TLMAX8  =                 4095
# TLMIN9  =                    0
# TLMAX9  =                 4095
# TLMIN10 =                    0
# TLMAX10 =                 4095
# TLMIN21 =                    0
# TLMAX21 =                  255
# TLMIN22 =                    0
# TLMAX22 =                 1023
# MTYPE1  = 'raw     '           / DM Keyword: Descriptor name.
# MFORM1  = 'rawx,rawy'          / [pixel]
# MTYPE2  = 'chip    '           / DM Keyword: Descriptor name.
# MFORM2  = 'chipx,chipy'        / [pixel]
# MTYPE3  = 'tdet    '           / DM Keyword: Descriptor name.
# MFORM3  = 'tdetx,tdety'        / [pixel]
# MTYPE4  = 'det     '           / DM Keyword: Descriptor name.
# MFORM4  = 'detx,dety'          / [pixel]
# MTYPE5  = 'sky     '           / DM Keyword: Descriptor name.
# MFORM5  = 'x,y     '           / [pixel]
# DSTYP1  = 'time    '           / DM Keyword: Descriptor name.
# DSVAL1  = 'TABLE   '           / [s]
# DSFORM1 = 'D       '           / DM Keyword: Descriptor datatype.
# DSUNIT1 = 's       '           / DM Keyword: Descriptor unit.
# DSREF1  = ':GTI    '
# DSTYP2  = 'MJF     '           / DM Keyword: Descriptor name.
# DSVAL2  = '0:131071'           / DM Keyword: Descriptor value.
# DSFORM2 = 'J       '           / DM Keyword: Descriptor datatype.
# DSTYP3  = 'MNF     '           / DM Keyword: Descriptor name.
# DSVAL3  = '0:127   '           / DM Keyword: Descriptor value.
# DSFORM3 = 'J       '           / DM Keyword: Descriptor datatype.
# DSTYP4  = 'ENDMNF  '           / DM Keyword: Descriptor name.
# DSVAL4  = '0:127   '           / DM Keyword: Descriptor value.
# DSFORM4 = 'J       '           / DM Keyword: Descriptor datatype.
# DSTYP5  = 'SUB_MJF '           / DM Keyword: Descriptor name.
# DSVAL5  = ':64     '           / DM Keyword: Descriptor value.
# DSFORM5 = 'B       '           / DM Keyword: Descriptor datatype.
# DSTYP6  = 'CLKTICKS'           / DM Keyword: Descriptor name.
# DSVAL6  = '0:1091567608'       / DM Keyword: Descriptor value.
# DSFORM6 = 'J       '           / DM Keyword: Descriptor datatype.
# MTYPE6  = 'CPC     '           / DM Keyword: Descriptor name.
# MFORM6  = 'CPCX,CPCY'          / [mm]
# TCTYP13 = 'CPCX    '
# TCRVL13 =  0.0000000000000E+00
# TCRPX13 =  5.0000000000000E-01
# TCDLT13 =  6.4294000000000E-03
# TCUNI13 = 'mm      '
# TCTYP14 = 'CPCY    '
# TCRVL14 =  0.0000000000000E+00
# TCRPX14 =  5.0000000000000E-01
# TCDLT14 =  6.4294000000000E-03
# TCUNI14 = 'mm      '
# MTYPE7  = 'MSC     '           / DM Keyword: Descriptor name.
# MFORM7  = 'PHI,THETA'          / [deg]
# TCTYP17 = 'LONG-TAN'
# TCRVL17 =  0.0000000000000E+00
# TCRPX17 =  1.6384500000000E+04
# TCDLT17 =  3.6611111111111E-05
# TCNA17  = 'PHI     '
# TCUNI17 = 'deg     '
# LONP17  =  2.7000000000000E+02
# LATP17  =  9.0000000000000E+01
# TCTYP18 = 'NPOL-TAN'
# TCRVL18 =  0.0000000000000E+00
# TCRPX18 =  1.6384500000000E+04
# TCDLT18 =  3.6611111111111E-05
# TCNA18  = 'THETA   '
# TCUNI18 = 'deg     '
# MTYPE8  = 'EQPOS   '           / DM Keyword: Descriptor name.
# MFORM8  = 'RA,DEC  '           / [deg]
# TCTYP19 = 'RA---TAN'
# TCRVL19 =  1.0109821091654E+01
# TCRPX19 =  1.6384500000000E+04
# TCDLT19 = -3.6611111111111E-05
# TCUNI19 = 'deg     '
# TCTYP20 = 'DEC--TAN'
# TCRVL20 =  4.0674572254271E+01
# TCRPX20 =  1.6384500000000E+04
# TCDLT20 =  3.6611111111111E-05
# TCUNI20 = 'deg     '
# HISTORY  TOOL  :mtl_build_gti   2012-09-23T15:08:56                     ASC00175
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00176
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_mtl1.fits         ASC00177
# HISTORY  PARM  :outfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00178
# HISTORY  CONT  :464699060n941/output/hrcf02886_000N004_evt1.fits        ASC00179
# HISTORY  PARM  :mtlfile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____ASC00180
# HISTORY  CONT  :464699060n941/output/hrcf02886_000N004_all_mtl1.fits    ASC00181
# HISTORY  PARM  :userlimit=                                              ASC00182
# HISTORY  PARM  :lkupfile=/home/ascds/DS.rap/data/hrc_gti_all_lim.fits   ASC00183
# HISTORY  PARM  :smooth=yes                                              ASC00184
# HISTORY  PARM  :clobber=no                                              ASC00185
# HISTORY  PARM  :verbose=0                                               ASC00186
# HISTORY  TOOL  :dmhedit   2012-09-23T15:10:58                           ASC00187
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00188
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits         ASC00189
# HISTORY  PARM  :filelist=none                                           ASC00190
# HISTORY  PARM  :operation=add                                           ASC00191
# HISTORY  PARM  :key=DTCOR                                               ASC00192
# HISTORY  PARM  :value=0.9944090600047319                                ASC00193
# HISTORY  PARM  :datatype=indef                                          ASC00194
# HISTORY  PARM  :unit=                                                   ASC00195
# HISTORY  PARM  :comment=Dead time correction                            ASC00196
# HISTORY  PARM  :verbose=0                                               ASC00197
# HISTORY  TOOL  :dmhedit   2012-09-23T15:10:59                           ASC00198
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00199
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits         ASC00200
# HISTORY  PARM  :filelist=none                                           ASC00201
# HISTORY  PARM  :operation=add                                           ASC00202
# HISTORY  PARM  :key=LIVETIME                                            ASC00203
# HISTORY  PARM  :value=947.920473909039                                  ASC00204
# HISTORY  PARM  :datatype=indef                                          ASC00205
# HISTORY  PARM  :unit=                                                   ASC00206
# HISTORY  PARM  :comment=Ontime multiplied by DTCOR                      ASC00207
# HISTORY  PARM  :verbose=0                                               ASC00208
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:01                           ASC00209
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00210
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits         ASC00211
# HISTORY  PARM  :filelist=none                                           ASC00212
# HISTORY  PARM  :operation=add                                           ASC00213
# HISTORY  PARM  :key=EXPOSURE                                            ASC00214
# HISTORY  PARM  :value=947.920473909039                                  ASC00215
# HISTORY  PARM  :datatype=indef                                          ASC00216
# HISTORY  PARM  :unit=                                                   ASC00217
# HISTORY  PARM  :comment=Total exposure time, with all known corr. appl. ASC00218
# HISTORY  PARM  :verbose=0                                               ASC00219
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:15                           ASC00220
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00221
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS],ASC00222
# HISTORY  CONT  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00223
# HISTORY  CONT  :0n941/output/hrcf02886_000N004_aoff1.fits[ASPOFF],/dsopsASC00224
# HISTORY  CONT  :/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____464699060n941/ASC00225
# HISTORY  CONT  :output/hrcf02886_000N004_soff1.fits[ALIGN],/dsops/repro4ASC00226
# HISTORY  CONT  :/sdp.1/opus/prs_run/tmp//HRC_L1____464699060n941/output/ASC00227
# HISTORY  CONT  :hrcf02886_000N004_std_flt1.fits[FILTER],/dsops/repro4/sdASC00228
# HISTORY  CONT  :p.1/opus/prs_run/tmp//HRC_L1____464699060n941/output/hrcASC00229
# HISTORY  CONT  :f02886_000N004_bpix1.fits[BADPIX],/dsops/repro4/sdp.1/opASC00230
# HISTORY  CONT  :us/prs_run/tmp//HRC_L1____464699060n941/output/hrcf02886ASC00231
# HISTORY  CONT  :_000N004_dtf1.fits[DTF],/dsops/repro4/sdp.1/opus/prs_runASC00232
# HISTORY  CONT  :/tmp//HRC_L1____464699060n941/output/hrcf02886_000N004_sASC00233
# HISTORY  CONT  :td_dtfstat1.fits[DTFSTATS]                              ASC00234
# HISTORY  PARM  :filelist=                                               ASC00235
# HISTORY  PARM  :operation=add                                           ASC00236
# HISTORY  PARM  :key=REVISION                                            ASC00237
# HISTORY  PARM  :value=4                                                 ASC00238
# HISTORY  PARM  :datatype=long                                           ASC00239
# HISTORY  PARM  :unit=                                                   ASC00240
# HISTORY  PARM  :comment=                                                ASC00241
# HISTORY  PARM  :verbose=0                                               ASC00242
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:22                           ASC00243
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00244
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00245
# HISTORY  PARM  :filelist=                                               ASC00246
# HISTORY  PARM  :operation=add                                           ASC00247
# HISTORY  PARM  :key=AIMPFILE                                            ASC00248
# HISTORY  PARM  :value=telD1999-07-23aimptsN0002.fits                    ASC00249
# HISTORY  PARM  :datatype=string                                         ASC00250
# HISTORY  PARM  :unit=                                                   ASC00251
# HISTORY  PARM  :comment=                                                ASC00252
# HISTORY  PARM  :verbose=0                                               ASC00253
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:25                           ASC00254
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00255
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00256
# HISTORY  PARM  :filelist=                                               ASC00257
# HISTORY  PARM  :operation=add                                           ASC00258
# HISTORY  PARM  :key=GEOMFILE                                            ASC00259
# HISTORY  PARM  :value=telD1999-07-23geomN0006.fits                      ASC00260
# HISTORY  PARM  :datatype=string                                         ASC00261
# HISTORY  PARM  :unit=                                                   ASC00262
# HISTORY  PARM  :comment=                                                ASC00263
# HISTORY  PARM  :verbose=0                                               ASC00264
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:29                           ASC00265
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00266
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00267
# HISTORY  PARM  :filelist=                                               ASC00268
# HISTORY  PARM  :operation=add                                           ASC00269
# HISTORY  PARM  :key=SKYFILE                                             ASC00270
# HISTORY  PARM  :value=telD1999-07-23skyN0002.fits                       ASC00271
# HISTORY  PARM  :datatype=string                                         ASC00272
# HISTORY  PARM  :unit=                                                   ASC00273
# HISTORY  PARM  :comment=                                                ASC00274
# HISTORY  PARM  :verbose=0                                               ASC00275
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:33                           ASC00276
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00277
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00278
# HISTORY  PARM  :filelist=                                               ASC00279
# HISTORY  PARM  :operation=add                                           ASC00280
# HISTORY  PARM  :key=TDETFILE                                            ASC00281
# HISTORY  PARM  :value=telD1999-07-23tdetN0001.fits                      ASC00282
# HISTORY  PARM  :datatype=string                                         ASC00283
# HISTORY  PARM  :unit=                                                   ASC00284
# HISTORY  PARM  :comment=                                                ASC00285
# HISTORY  PARM  :verbose=0                                               ASC00286
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:36                           ASC00287
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00288
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00289
# HISTORY  PARM  :filelist=                                               ASC00290
# HISTORY  PARM  :operation=add                                           ASC00291
# HISTORY  PARM  :key=SHELLFIL                                            ASC00292
# HISTORY  PARM  :value=telD1999-07-23sgeomN0001.fits                     ASC00293
# HISTORY  PARM  :datatype=string                                         ASC00294
# HISTORY  PARM  :unit=                                                   ASC00295
# HISTORY  PARM  :comment=                                                ASC00296
# HISTORY  PARM  :verbose=0                                               ASC00297
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:38                           ASC00298
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00299
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00300
# HISTORY  PARM  :filelist=                                               ASC00301
# HISTORY  PARM  :operation=add                                           ASC00302
# HISTORY  PARM  :key=DTFFILE                                             ASC00303
# HISTORY  PARM  :value='hrcf02886_000N004_dtf1.fits'                     ASC00304
# HISTORY  PARM  :datatype=string                                         ASC00305
# HISTORY  PARM  :unit=                                                   ASC00306
# HISTORY  PARM  :comment=                                                ASC00307
# HISTORY  PARM  :verbose=0                                               ASC00308
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:40                           ASC00309
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00310
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00311
# HISTORY  PARM  :filelist=                                               ASC00312
# HISTORY  PARM  :operation=add                                           ASC00313
# HISTORY  PARM  :key=MASKFILE                                            ASC00314
# HISTORY  PARM  :value='hrcf02886_000N004_msk1.fits'                     ASC00315
# HISTORY  PARM  :datatype=string                                         ASC00316
# HISTORY  PARM  :unit=                                                   ASC00317
# HISTORY  PARM  :comment=                                                ASC00318
# HISTORY  PARM  :verbose=0                                               ASC00319
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:41                           ASC00320
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00321
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS] ASC00322
# HISTORY  PARM  :filelist=                                               ASC00323
# HISTORY  PARM  :operation=add                                           ASC00324
# HISTORY  PARM  :key=FLTFILE                                             ASC00325
# HISTORY  PARM  :value='hrcf02886_000N004_std_flt1.fits'                 ASC00326
# HISTORY  PARM  :datatype=string                                         ASC00327
# HISTORY  PARM  :unit=                                                   ASC00328
# HISTORY  PARM  :comment=                                                ASC00329
# HISTORY  PARM  :verbose=0                                               ASC00330
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:49                           ASC00331
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00332
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS][ASC00333
# HISTORY  CONT  :events]                                                 ASC00334
# HISTORY  PARM  :filelist=.//28640.hdr                                   ASC00335
# HISTORY  PARM  :operation=add                                           ASC00336
# HISTORY  PARM  :key=FLTFILE                                             ASC00337
# HISTORY  PARM  :value='hrcf02886_000N004_std_flt1.fits'                 ASC00338
# HISTORY  PARM  :datatype=indef                                          ASC00339
# HISTORY  PARM  :unit=                                                   ASC00340
# HISTORY  PARM  :comment=                                                ASC00341
# HISTORY  PARM  :verbose=0                                               ASC00342
# HISTORY  TOOL  :dmhedit   2012-09-23T15:11:52                           ASC00343
# HISTORY  PARM  :infile=/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____4ASC00344
# HISTORY  CONT  :64699060n941/output/hrcf02886_000N004_evt1.fits[EVENTS],ASC00345
# HISTORY  CONT  :/dsops/repro4/sdp.1/opus/prs_run/tmp//HRC_L1____46469906ASC00346
# HISTORY  CONT  :0n941/output/hrcf02886_000N004_mtl1.fits[MTL],/dsops/repASC00347
# HISTORY  CONT  :ro4/sdp.1/opus/prs_run/tmp//HRC_L1____464699060n941/outpASC00348
# HISTORY  CONT  :ut/hrcf02886_000N004_mtl1.fits[MTL_S],/dsops/repro4/sdp.ASC00349
# HISTORY  CONT  :1/opus/prs_run/tmp//HRC_L1____464699060n941/output/hrcf0ASC00350
# HISTORY  CONT  :2886_000N004_mtl1.fits[LIMITS],/dsops/repro4/sdp.1/opus/ASC00351
# HISTORY  CONT  :prs_run/tmp//HRC_L1____464699060n941/output/hrcf02886_00ASC00352
# HISTORY  CONT  :0N004_bpix1.fits[BADPIX],/dsops/repro4/sdp.1/opus/prs_ruASC00353
# HISTORY  CONT  :n/tmp//HRC_L1____464699060n941/output/hrcf02886_000N004_ASC00354
# HISTORY  CONT  :fov1.fits[FOV]                                          ASC00355
# HISTORY  PARM  :filelist=                                               ASC00356
# HISTORY  PARM  :operation=add                                           ASC00357
# HISTORY  PARM  :key=CALDBVER                                            ASC00358
# HISTORY  PARM  :value=' 4.5.1.1  '                                      ASC00359
# HISTORY  PARM  :datatype=string                                         ASC00360
# HISTORY  PARM  :unit=                                                   ASC00361
# HISTORY  PARM  :comment=                                                ASC00362
# HISTORY  PARM  :verbose=0                                               ASC00363

# %%
from hyperscreen import hypercore
