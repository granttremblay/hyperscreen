# %% [markdown]
# <img src='https://hyperscreen.readthedocs.io/en/latest/_images/hyperscreen_logo.png'>
#
# ### A Tour of HyperScreen

# %%
import os
from hyperscreen import hypercore

# %%
data_dir = '../tests/data/'
os.listdir(data_dir)
# Out:
# ['hrcI_evt1_testfile.fits.gz',
#  'hrcS_evt1_sparsetap_testfile.fits.gz',
#  'hrcI_evt1_casAtest.fits.gz',
#  'hrcS_evt1_testfile.fits.gz']

# %%
data_file = data_dir + '/hrcI_evt1_casAtest.fits.gz'

# %%
obs = hypercore.HRCevt1(data_file)

# %%
obs.image()

# %%
obs.image(masked_x = obs.data['x'][obs.gtimask], masked_y = obs.data['y'][obs.gtimask])

# %%
mask = obs.data['Hyperbola test failed']
obs.image(masked_x = obs.data['x'][mask], masked_y = obs.data['y'][mask])

# %%
mask_steve = obs.data['Hyperbola test failed']
obs.image(masked_x = obs.data['x'][mask], masked_y = obs.data['y'][mask])

# %%
tremblay = obs.hyperscreen()

# %%
mask_grant = tremblay['All Survivals (boolean mask)']
obs.image(masked_x = obs.data['x'][mask], masked_y = obs.data['y'][mask])
